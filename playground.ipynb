# %%
import json
import networkx as nx
import matplotlib.pyplot as plt

# %%
def read_data(filename, idx):
    with open(filename, 'r') as f:
        for i, line in enumerate(f):
            if i == idx:
                data = json.loads(line)
                break
        else:
            raise IndexError(f"Line index {idx} out of range.")
    return data

# %%
def read_graph(filename, idx):
    with open(filename, 'r') as f:
        for i, line in enumerate(f):
            if i == idx:
                data = json.loads(line)
                graph_data = data['graph']
                break
        else:
            raise IndexError(f"Line index {idx} out of range.")

    G = nx.Graph()  # simple, undirected graph

    # Add nodes
    for node in graph_data["nodes"]:
        G.add_node(node["id"])

    # Add edges
    for edge in graph_data["edges"]:
        G.add_edge(edge["source"], edge["target"], weight=edge.get("weight", 1.0))

    return G

# %%
read_data("failing_graphs.jsonl", 1)
# Out:
# {'graph': {'directed': False,
#   'multigraph': False,
#   'graph': {},
#   'nodes': [{'id': 0},
#    {'id': 1},
#    {'id': 2},
#    {'id': 3},
#    {'id': 4},
#    {'id': 5},
#    {'id': 6},
#    {'id': 7},
#    {'id': 8},
#    {'id': 9}],
#   'edges': [{'weight': 1.0, 'source': 0, 'target': 6},
#    {'weight': 1.0, 'source': 0, 'target': 7},
#    {'weight': 1.0, 'source': 0, 'target': 9},
#    {'weight': 1.0, 'source': 1, 'target': 6},
#    {'weight': 1.0, 'source': 1, 'target': 7},
#    {'weight': 1.0, 'source': 1, 'target': 9},
#    {'weight': 1.0, 'source': 2, 'target': 6},
#    {'weight': 1.0, 'source': 2, 'target': 7},
#    {'weight': 1.0, 'source': 2, 'target': 9},
#    {'weight': 1.0, 'source': 3, 'target': 8},
#    {'weight': 1.0, 'source': 3, 'target': 9},
#    {'weight': 1.0, 'source': 4, 'target': 8},
#    {'weight': 1.0, 'source': 4, 'target': 9},
#    {'weight': 1.0, 'source': 5, 'target': 8},
#    {'weight': 1.0, 'source': 6, 'target': 8},
# ...

# %%
14/18.67
# Out:
# 0.7498660953401177

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
fig.set_figheight(2)
fig.set_figwidth(8)
nx.draw(read_graph("failing_graphs.jsonl", 0), node_size=50, ax=axs[0])
nx.draw(read_graph("failing_graphs.jsonl", 1), node_size=50, ax=axs[1])
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
fig.set_figheight(3)
fig.set_figwidth(6)
nx.draw(read_graph("failing_graphs.jsonl", 2), node_size=50)
plt.show()
